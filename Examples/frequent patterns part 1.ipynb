# %% [markdown]
# This notebook shows an example of generating rules for frequent patterns.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

df = pd.read_excel('http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
basket = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# ...

# %% [markdown]
# Set the cell contents to meaningful values for market basket calculations:  if cell > 0, cell = 1  if cell < 0, cell = 0.

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %% [markdown]
# Now we are ready to generate itemsets.

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
frequent_itemsets.head()
# Out:
#     support                        itemsets
# 0  0.071429   (4 TRADITIONAL SPINNING TOPS)
# 1  0.096939    (ALARM CLOCK BAKELIKE GREEN)
# 2  0.102041     (ALARM CLOCK BAKELIKE PINK)
# 3  0.094388      (ALARM CLOCK BAKELIKE RED)
# 4  0.081633  (BAKING SET 9 PIECE RETROSPOT)

# %% [markdown]
# And now we can use the item sets to generate association rules

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                                          antecedents  \
# 0  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 1  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 2  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 3                    (SET/6 RED SPOTTY PAPER PLATES)
# 4               (SET/20 RED RETROSPOT PAPER NAPKINS)
#
#                                          consequents  antecedent support  \
# 0                      (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 1               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.122449
# 2                    (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 3  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.127551
# 4  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...            0.132653
#
#    consequent support  support  confidence      lift  leverage  conviction
# 0            0.137755  0.09949      0.9750  7.077778  0.085433   34.489796
# ...
